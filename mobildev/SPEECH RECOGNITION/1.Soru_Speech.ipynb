# %% [markdown]
# **1.SORU**
#
# DeepSeech ile çalıştım.Linux kurulu olan bilgisayarda depolama alanı sorunundan eğitim kısmı yarım kaldı.

# %%
import os
# !git clone https://github.com/mozilla/DeepSpeech.git
os.chdir("DeepSpeech")
# Out:
# Cloning into 'DeepSpeech'...
# Updating files:  60% (1337/2205)
# Updating files:  61% (1346/2205)
# Updating files:  62% (1368/2205)
# Updating files:  63% (1390/2205)
# Updating files:  64% (1412/2205)
# Updating files:  65% (1434/2205)
# Updating files:  66% (1456/2205)
# Updating files:  67% (1478/2205)
# Updating files:  68% (1500/2205)
# Updating files:  69% (1522/2205)
# Updating files:  70% (1544/2205)
# Updating files:  71% (1566/2205)
# Updating files:  72% (1588/2205)
# Updating files:  73% (1610/2205)
# Updating files:  74% (1632/2205)
# Updating files:  75% (1654/2205)
# Updating files:  76% (1676/2205)
# Updating files:  77% (1698/2205)
# Updating files:  78% (1720/2205)
# Updating files:  79% (1742/2205)
# Updating files:  80% (1764/2205)
# Updating files:  81% (1787/2205)
# Updating files:  82% (1809/2205)
# Updating files:  83% (1831/2205)
# Updating files:  84% (1853/2205)
# Updating files:  85% (1875/2205)
# Updating files:  86% (1897/2205)
# ...

# %%
import os
! pwd
os.chdir("/media/delibas/DEPO/SpeechRecognition/DeepSpeech")
# Out:
# /media/delibas/DEPO/SpeechRecognition/DeepSpeech

# %%
# ! Hangi dilde eğitim yapıyorsak alfabe oluşturulması gerekiyor.
alphabet = """a
b
c
ç
d
e
f
g
ğ
h
i
ı
j
k
l
m
n
o
ö
p
r
s
ş
t
u
ü
v
y
z
"""
open("alphabet.txt", "w").write(alphabet)
# !python3 bin/import_cv2.py --filter_alphabet "alphabet.txt" "/media/delibas/DEPO/SpeechRecognition/cv-corpus-9.0-2022-04-27/tr"
# Out:
# Loading TSV file:  /media/delibas/DEPO/SpeechRecognition/cv-corpus-9.0-2022-04-27/tr/test.tsv
# Importing mp3 files...
# WARNING: No --validate_label_locale specified, your might end with inconsistent dataset.
# WARNING: No --validate_label_locale specified, your might end with inconsistent dataset.
# WARNING: No --validate_label_locale specified, your might end with inconsistent dataset.
# WARNING: No --validate_label_locale specified, your might end with inconsistent dataset.
# Progress |#################################################### |  98% completedImported 406 samples.
# Skipped 7956 samples that failed on transcript validation.
# Final amount of imported audio: 0:17:25 from 9:34:44.
# Saving new DeepSpeech-formatted CSV file to:  /media/delibas/DEPO/SpeechRecognition/cv-corpus-9.0-2022-04-27/tr/clips/test.csv
# Writing CSV file for DeepSpeech.py as:  /media/delibas/DEPO/SpeechRecognition/cv-corpus-9.0-2022-04-27/tr/clips/test.csv
# ...

# %%
# !python3 DeepSpeech.py --train_files "/media/delibas/DEPO/SpeechRecognition/cv-corpus-5-2020-06-22/tr/clips/train.csv" --dev_files "/media/delibas/DEPO/SpeechRecognition/cv-corpus-5-2020-06-22/tr/clips/dev.csv" --test_files "/media/delibas/DEPO/SpeechRecognition/cv-corpus-5-2020-06-22/tr/clips/test.csv" --export_dir ~/deepspeech_checkpoints
# Out:
# /home/delibas/.local/lib/python3.6/site-packages/numba/core/errors.py:154: UserWarning: Insufficiently recent colorama version found. Numba requires colorama >= 0.3.9
#   warnings.warn(msg)
# I Could not find best validating checkpoint.
# I Could not find most recent checkpoint.
# I Initializing all variables.
# I STARTING Optimization
# Epoch 0 |   Training | Elapsed Time: 0:00:00 | Steps: 0 | Loss: 0.000000       Traceback (most recent call last):
#   File "/home/delibas/.local/lib/python3.6/site-packages/tensorflow_core/python/client/session.py", line 1365, in _do_call
#     return fn(*args)
#   File "/home/delibas/.local/lib/python3.6/site-packages/tensorflow_core/python/client/session.py", line 1350, in _run_fn
#     target_list, run_metadata)
#   File "/home/delibas/.local/lib/python3.6/site-packages/tensorflow_core/python/client/session.py", line 1443, in _call_tf_sessionrun
#     run_metadata)
# tensorflow.python.framework.errors_impl.OutOfRangeError: End of sequence
# ...
